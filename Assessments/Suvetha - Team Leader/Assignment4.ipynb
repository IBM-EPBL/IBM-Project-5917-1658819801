# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.models import Model,Sequential
from keras.layers import LSTM, Activation, Dense, Dropout, Input, Embedding
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/IBM/spam.csv',encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   v1      5572 non-null   object
#  1   v2      5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sns.countplot(df.v1)
plt.xlabel('Label')
plt.title('Number of ham and spam messages')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Number of ham and spam messages')

# %%
X = df.v2
Y = df.v1
le = LabelEncoder()
Y = le.fit_transform(Y)
Y = Y.reshape(-1,1)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.15)

# %%
max_words = 1000
max_len = 150
tok = Tokenizer(num_words=max_words)
tok.fit_on_texts(X_train)
sequences = tok.texts_to_sequences(X_train)
sequences_matrix = pad_sequences(sequences,maxlen=max_len)
sequences_matrix
# Out:
# array([[  0,   0,   0, ...,  12,  43,  42],
#        [  0,   0,   0, ..., 640, 907, 464],
#        [  0,   0,   0, ..., 226, 391, 709],
#        ...,
#        [  0,   0,   0, ..., 188,  44, 129],
#        [  0,   0,   0, ...,  54,   4, 289],
#        [  0,   0,   0, ..., 394, 119,   6]], dtype=int32)

# %%
tok.index_word
# Out:
# {1: 'i',
#  2: 'to',
#  3: 'you',
#  4: 'a',
#  5: 'the',
#  6: 'u',
#  7: 'and',
#  8: 'is',
#  9: 'in',
#  10: 'me',
#  11: 'my',
#  12: 'for',
#  13: 'your',
#  14: 'it',
#  15: 'of',
#  16: 'call',
#  17: 'have',
#  18: 'on',
#  19: '2',
#  20: 'are',
#  21: 'that',
#  22: 'now',
#  23: 'so',
#  24: 'or',
#  25: 'not',
#  26: 'but',
#  27: 'can',
#  28: 'at',
#  29: 'do',
#  30: "i'm",
#  31: 'get',
#  32: 'will',
#  33: 'ur',
#  34: 'be',
#  35: 'with',
#  36: 'if',
#  37: 'just',
#  38: 'we',
#  39: 'no',
#  40: 'this',
#  41: '4',
#  42: 'gt',
#  43: 'lt',
#  44: 'up',
#  45: 'how',
#  46: 'free',
#  47: 'from',
#  48: 'when',
#  49: 'ok',
#  50: 'go',
#  51: 'all',
#  52: 'know',
#  53: 'what',
#  54: 'out',
#  55: 'then',
#  56: 'like',
#  57: 'good',
#  58: 'was',
#  59: 'got',
#  60: 'come',
#  61: 'am',
#  62: 'time',
#  63: 'day',
#  64: 'only',
#  65: 'its',
#  66: 'love',
#  67: 'send',
#  68: 'there',
#  69: 'he',
#  70: 'want',
#  71: 'text',
#  72: 'as',
#  73: 'txt',
#  74: 'going',
#  75: 'one',
#  76: 'home',
#  77: 'by',
#  78: 'need',
#  79: 'stop',
#  80: 'lor',
#  81: 'about',
#  82: 'r',
#  83: "i'll",
#  84: 'back',
#  85: 'still',
#  86: 'sorry',
#  87: 'today',
#  88: 'da',
#  89: 'reply',
#  90: 'our',
#  91: 'see',
#  92: 'n',
#  93: 'mobile',
#  94: 'dont',
#  95: 'pls',
#  96: "don't",
#  97: 'she',
#  98: 'later',
#  99: 'k',
#  100: 'hi',
#  101: 'tell',
#  102: 'take',
#  103: 'her',
#  104: 'any',
#  105: 'please',
#  106: 'new',
#  107: 'think',
#  108: 'they',
#  109: 'phone',
#  110: 'great',
#  111: 'ì',
#  112: 'been',
#  113: 'claim',
#  114: 'hope',
#  115: '1',
#  116: 'here',
#  117: 'has',
#  118: 'much',
#  119: 'msg',
#  120: 'dear',
#  121: 'd',
#  122: 'night',
#  123: 'week',
#  124: 'hey',
#  125: 'had',
#  126: 'oh',
#  127: 'who',
#  128: 'well',
#  129: 'more',
#  130: 'him',
#  131: 'did',
#  132: 'c',
#  133: 'some',
#  134: 'an',
#  135: 'happy',
#  136: 'yes',
#  137: 'way',
#  138: 'too',
#  139: 'where',
#  140: 'prize',
#  141: 'www',
#  142: 'number',
#  143: 'already',
#  144: 'e',
#  145: "it's",
#  146: 'say',
#  147: 'wat',
#  148: 'work',
#  149: 'tomorrow',
#  150: 'message',
#  151: 'make',
#  152: 'should',
#  153: 'give',
#  154: 'cash',
#  155: 'said',
#  156: 'amp',
#  157: 'after',
#  158: 'right',
#  159: 'doing',
#  160: 'life',
#  161: 'meet',
#  162: '3',
#  163: 'ask',
#  164: 'why',
#  165: 'yeah',
#  166: 'really',
#  167: 'them',
#  168: 'win',
#  169: 't',
#  170: 'won',
#  171: 'last',
#  172: 'im',
#  173: 'thanks',
#  174: 'find',
#  175: 'babe',
#  176: 'morning',
#  177: 'miss',
#  178: 'very',
#  179: 'urgent',
#  180: 'let',
#  181: 'every',
#  182: 'b',
#  183: 'would',
#  184: 'cos',
#  185: '150p',
#  186: 'nokia',
#  187: 'lol',
#  188: 'pick',
#  189: 'uk',
#  190: 'contact',
#  191: 'anything',
#  192: 'also',
#  193: 'keep',
#  194: 'us',
#  195: 'over',
#  196: 'com',
#  197: 'care',
#  198: 'before',
#  199: 'again',
#  200: 'sent',
#  201: 'even',
#  202: 'nice',
#  203: 's',
#  204: 'something',
#  205: '5',
#  206: 'feel',
#  207: 'buy',
#  208: 'sure',
#  209: 'soon',
#  210: 'tonight',
#  211: 'service',
#  212: 'first',
#  213: 'money',
#  214: 'thing',
#  215: 'went',
#  216: '50',
#  217: "can't",
#  218: 'down',
#  219: 'could',
#  220: 'min',
#  221: 'wait',
#  222: 'off',
#  223: 'tone',
#  224: 'cant',
#  225: 'were',
#  226: 'sleep',
#  227: 'place',
#  228: 'gud',
#  229: "i've",
#  230: 'late',
#  231: 'co',
#  232: 'many',
#  233: 'always',
#  234: 'next',
#  235: 'per',
#  236: 'wan',
#  237: '18',
#  238: 'gonna',
#  239: 'which',
#  240: 'ya',
#  241: 'his',
#  242: 'hello',
#  243: 'chat',
#  244: 'leave',
#  245: 'around',
#  246: 'coming',
#  247: "that's",
#  248: 'dun',
#  249: 'v',
#  250: 'x',
#  251: 'someone',
#  252: 'name',
#  253: 'told',
#  254: 'waiting',
#  255: 'other',
#  256: 'guaranteed',
#  257: 'customer',
#  258: 'sms',
#  259: 'things',
#  260: 'ìï',
#  261: 'help',
#  262: 'people',
#  263: 'thk',
#  264: 'holiday',
#  265: 'friends',
#  266: '16',
#  267: 'year',
#  268: 'done',
#  269: 'same',
#  270: 'wish',
#  271: 'use',
#  272: 'yet',
#  273: "you're",
#  274: 'fine',
#  275: 'lunch',
#  276: 'talk',
#  277: 'getting',
#  278: 'special',
#  279: 'try',
#  280: 'haha',
#  281: 'being',
#  282: 'friend',
#  283: 'may',
#  284: 'best',
#  285: 'few',
#  286: 'line',
#  287: 'mins',
#  288: 'trying',
#  289: 'bit',
#  290: 'smile',
#  291: 'days',
#  292: 'ready',
#  293: 'house',
#  294: 'y',
#  295: 'long',
#  296: 'heart',
#  297: 'draw',
#  298: 'job',
#  299: 'yo',
#  300: 'cs',
#  301: 'live',
#  302: 'ill',
#  303: '7',
#  304: 'thought',
#  305: 'man',
#  306: 'having',
#  307: 'cool',
#  308: 'class',
#  309: 'receive',
#  310: 'nothing',
#  311: '6',
#  312: 'dat',
#  313: 'lar',
#  314: "didn't",
#  315: 'better',
#  316: 'wk',
#  317: 'meeting',
#  318: 'eat',
#  319: 'liao',
#  320: 'another',
#  321: 'never',
#  322: 'lot',
#  323: 'chance',
#  324: 'thats',
#  325: 'mind',
#  326: 'god',
#  327: 'yup',
#  328: 'account',
#  329: 'real',
#  330: 'person',
#  331: 'problem',
#  332: 'stuff',
#  333: 'awarded',
#  334: 'car',
#  335: 'might',
#  336: 'latest',
#  337: 'end',
#  338: 'play',
#  339: 'å£1',
#  340: 'than',
#  341: 'enjoy',
#  342: 'because',
#  343: 'word',
#  344: 'world',
#  345: 'big',
#  346: 'month',
#  347: 'sir',
#  348: 'bt',
#  349: 'video',
#  350: 'guys',
#  351: 'start',
#  352: 'boy',
#  353: 'ever',
#  354: 'birthday',
#  355: 'camera',
#  356: 'guess',
#  357: 'å£1000',
#  358: 'apply',
#  359: 'into',
#  360: 'called',
#  361: 'watching',
#  362: '150ppm',
#  363: 'box',
#  364: 'girl',
#  365: 'xxx',
#  366: 'shows',
#  367: 'shit',
#  368: 'aight',
#  369: 'finish',
#  370: 'jus',
#  371: 'pay',
#  372: 'quite',
#  373: 'luv',
#  374: 'dinner',
#  375: 'once',
#  376: 'room',
#  377: 'half',
#  378: 'shall',
#  379: 'ah',
#  380: 'landline',
#  381: 'offer',
#  382: 'speak',
#  383: 'kiss',
#  384: '1st',
#  385: 'rate',
#  386: 'two',
#  387: 'pa',
#  388: 'dunno',
#  389: 'po',
#  390: 'cost',
#  391: 'sweet',
#  392: 'didnt',
#  393: 'code',
#  394: 'den',
#  395: 'wont',
#  396: 'shopping',
#  397: 'reach',
#  398: 'probably',
#  399: 'look',
#  400: '000',
#  401: 'sat',
#  402: 'princess',
#  403: 'between',
#  404: '10',
#  405: 'award',
#  406: 'network',
#  407: 'check',
#  408: 'part',
#  409: 'remember',
#  410: 'hear',
#  411: 'll',
#  412: 'xmas',
#  413: 'bed',
#  414: 'maybe',
#  415: 'join',
#  416: 'forgot',
#  417: 'selected',
#  418: 'actually',
#  419: 'm',
#  420: "how's",
#  421: 'leh',
#  422: 'dad',
#  423: 'minutes',
#  424: 'easy',
#  425: 'school',
#  426: 'entry',
#  427: 'tv',
#  428: 'thanx',
#  429: 'does',
#  430: 'plan',
#  431: 'watch',
#  432: 'early',
#  433: 'working',
#  434: 'orange',
#  435: 'calls',
#  436: 'anyway',
#  437: 'collection',
#  438: 'office',
#  439: 'wanna',
#  440: 'bus',
#  441: 'put',
#  442: 'bad',
#  443: 'came',
#  444: 'wife',
#  445: 'fun',
#  446: '2nd',
#  447: 'left',
#  448: 'weekend',
#  449: 'wif',
#  450: 'able',
#  451: 'afternoon',
#  452: 'wake',
#  453: 'yesterday',
#  454: 'everything',
#  455: 'abt',
#  456: 'pain',
#  457: 'most',
#  458: 'sexy',
#  459: '8',
#  460: 'fuck',
#  461: 'tmr',
#  462: 'collect',
#  463: 'ringtone',
#  464: 'details',
#  465: "there's",
#  466: 'since',
#  467: 'else',
#  468: 'town',
#  469: "he's",
#  470: 'little',
#  471: 'without',
#  472: 'texts',
#  473: 'update',
#  474: 'attempt',
#  475: 'baby',
#  476: 'havent',
#  477: 'g',
#  478: '9',
#  479: 'enough',
#  480: 'face',
#  481: 'mob',
#  482: 'looking',
#  483: 'evening',
#  484: 'these',
#  485: 'away',
#  486: 'plus',
#  487: 'de',
#  488: 'valid',
#  489: 'nite',
#  490: 'change',
#  491: 'bring',
#  492: 'missing',
#  493: 'show',
#  494: 'though',
#  495: 'okay',
#  496: 'weekly',
#  497: 'until',
#  498: 'must',
#  499: '10p',
#  500: "haven't",
#  501: 'decimal',
#  502: 'online',
#  503: 'words',
#  504: 'run',
#  505: 'tones',
#  506: 'made',
#  507: 'those',
#  508: 'hav',
#  509: 'dis',
#  510: 'says',
#  511: 'missed',
#  512: 'while',
#  513: 'wen',
#  514: 'saw',
#  515: 'hour',
#  516: 'years',
#  517: 'tot',
#  518: 'mail',
#  519: 'shop',
#  520: 'means',
#  521: 'plz',
#  522: 'tried',
#  523: 'national',
#  524: 'times',
#  525: 'important',
#  526: 'net',
#  527: 'goes',
#  528: 'å£100',
#  529: 're',
#  530: 'juz',
#  531: 'music',
#  532: 'gift',
#  533: 'making',
#  534: 'guy',
#  535: 'price',
#  536: 'todays',
#  537: 'goin',
#  538: 'lose',
#  539: 'full',
#  540: 'oso',
#  541: 'await',
#  542: 'sae',
#  543: 'asked',
#  544: 'å£5000',
#  545: 'either',
#  546: 'till',
#  547: 'bonus',
#  548: 'worry',
#  549: 'stay',
#  550: "what's",
#  551: 'book',
#  552: 'question',
#  553: 'smiling',
#  554: 'movie',
#  555: 'true',
#  556: 'both',
#  557: 'makes',
#  558: 'wot',
#  559: 'leaving',
#  560: 'row',
#  561: 'sleeping',
#  562: 'calling',
#  563: 'dude',
#  564: 'feeling',
#  565: 'chikku',
#  566: 'alright',
#  567: 'pics',
#  568: 'family',
#  569: 'ring',
#  570: 'sch',
#  571: 'haf',
#  572: 'hot',
#  573: 'wanted',
#  574: 'http',
#  575: '8007',
#  576: 'coz',
#  577: 'lei',
#  578: 'busy',
#  579: "''",
#  580: 'date',
#  581: '500',
#  582: 'mean',
#  583: 'yourself',
#  584: 'ard',
#  585: '750',
#  586: 'delivery',
#  587: "we're",
#  588: 'lets',
#  589: 'thank',
#  590: 'awesome',
#  591: 'id',
#  592: 'wants',
#  593: 'å£2000',
#  594: 'hair',
#  595: 'double',
#  596: 'pub',
#  597: 'eve',
#  598: 'beautiful',
#  599: 'colour',
#  600: 'top',
#  601: 'saying',
#  602: 'huh',
#  603: 'yours',
#  604: 'order',
#  605: 'news',
#  606: 'answer',
#  607: 'started',
#  608: 'messages',
#  609: 'å£500',
#  610: 'hours',
#  611: 'wid',
#  612: 'friendship',
#  613: 'touch',
#  614: 'land',
#  615: 'private',
#  616: 'points',
#  617: 'rite',
#  618: 'charge',
#  619: '12hrs',
#  620: 'old',
#  621: 'tho',
#  622: 'comes',
#  623: 'pm',
#  624: 'believe',
#  625: 'bored',
#  626: 'minute',
#  627: 'search',
#  628: 'pic',
#  629: 'together',
#  630: 'set',
#  631: 'poly',
#  632: 'thinking',
#  633: 'vouchers',
#  634: 'club',
#  635: 'address',
#  636: "c's",
#  637: 'post',
#  638: 'noe',
#  639: 'congrats',
#  640: 'company',
#  641: 'trip',
#  642: 'finished',
#  643: 'test',
#  644: 'lucky',
#  645: 'drive',
#  646: 'w',
#  647: 'break',
#  648: 'taking',
#  649: 'game',
#  650: 'games',
#  651: 'drink',
#  652: 'happen',
#  653: 'til',
#  654: 'walk',
#  655: 'brother',
#  656: 'close',
#  657: 'dating',
#  658: 'story',
#  659: 'unsubscribe',
#  660: 'gd',
#  661: 'final',
#  662: 'email',
#  663: 'driving',
#  664: 'pounds',
#  665: 'neva',
#  666: 'gr8',
#  667: 'took',
#  668: 'forget',
#  669: '86688',
#  670: 'each',
#  671: 'suite342',
#  672: '2lands',
#  673: 'anytime',
#  674: '08000930705',
#  675: 'statement',
#  676: 'opt',
#  677: 'sister',
#  678: 'don',
#  679: 'nt',
#  680: 'needs',
#  681: "we'll",
#  682: 'xx',
#  683: 'fri',
#  684: 'nope',
#  685: 'rs',
#  686: 'ha',
#  687: 'boytoy',
#  688: 'whatever',
#  689: 'angry',
#  690: 'hurt',
#  691: 'sad',
#  692: 'mine',
#  693: 'hit',
#  694: 'ltd',
#  695: 'aft',
#  696: 'second',
#  697: 'card',
#  698: 'sis',
#  699: 'open',
#  700: 'knw',
#  701: 'food',
#  702: 'alone',
#  703: 'saturday',
#  704: 'wit',
#  705: 'available',
#  706: 'frnd',
#  707: 'okie',
#  708: 'happened',
#  709: 'dreams',
#  710: "won't",
#  711: 'identifier',
#  712: 'expires',
#  713: 'drop',
#  714: 'mum',
#  715: 'operator',
#  716: 'sea',
#  717: 'course',
#  718: 'welcome',
#  719: '11',
#  720: 'pobox',
#  721: 'college',
#  722: 'f',
#  723: 'auction',
#  724: 'wil',
#  725: 'friday',
#  726: 'wonderful',
#  727: 'sunday',
#  728: 'weeks',
#  729: 'case',
#  730: 'treat',
#  731: 'fast',
#  732: 'hard',
#  733: 'msgs',
#  734: "you've",
#  735: '30',
#  736: 'choose',
#  737: 'chennai',
#  738: 'player',
#  739: 'least',
#  740: 'finally',
#  741: 'sounds',
#  742: 'carlos',
#  743: 'head',
#  744: 'outside',
#  745: 'everyone',
#  746: 'snow',
#  747: 'project',
#  748: 'content',
#  749: '100',
#  750: 'hold',
#  751: 'gone',
#  752: 'smth',
#  753: 'å£350',
#  754: 'camcorder',
#  755: 'na',
#  756: 'voucher',
#  757: '03',
#  758: 'party',
#  759: 'sun',
#  760: 'cum',
#  761: 'talking',
#  762: 'ass',
#  763: 'whole',
#  764: 'smoke',
#  765: 'etc',
#  766: 'å£250',
#  767: 'earlier',
#  768: 'mates',
#  769: 'goodmorning',
#  770: 'caller',
#  771: 'hand',
#  772: 'visit',
#  773: 'å£2',
#  774: 'å£3',
#  775: 'oredi',
#  776: 'fucking',
#  777: 'freemsg',
#  778: 'congratulations',
#  779: 'whats',
#  780: 'info',
#  781: 'unlimited',
#  782: 'wkly',
#  783: 'darlin',
#  784: 'crazy',
#  785: 'tomo',
#  786: "doesn't",
#  787: 'girls',
#  788: 'ni8',
#  789: 'anyone',
#  790: 'type',
#  791: 'far',
#  792: "she's",
#  793: 'support',
#  794: 'hows',
#  795: 'lovely',
#  796: 'phones',
#  797: 'mobileupd8',
#  798: 'almost',
#  799: 'numbers',
#  800: "you'll",
#  801: 'ends',
#  802: 'credit',
#  803: 'mrng',
#  804: 'comp',
#  805: 'telling',
#  806: 'complimentary',
#  807: 'met',
#  808: 'quiz',
#  809: 'listen',
#  810: 'winner',
#  811: 'couple',
#  812: 'worth',
#  813: 'uncle',
#  814: 'lots',
#  815: 'stupid',
#  816: 'india',
#  817: 'tc',
#  818: 'secret',
#  819: 'seeing',
#  820: 'cause',
#  821: 'semester',
#  822: 'found',
#  823: 'eh',
#  824: 'ago',
#  825: '0800',
#  826: 'understand',
#  827: 'ipod',
#  828: 'kind',
#  829: 'hmmm',
#  830: 'lesson',
#  831: 'loving',
#  832: 'frm',
#  833: 'ac',
#  834: 'age',
#  835: 'their',
#  836: 'frnds',
#  837: 'reading',
#  838: 'parents',
#  839: 'hmm',
#  840: 'b4',
#  841: 'pretty',
#  842: 'motorola',
#  843: 'dnt',
#  844: 'bout',
#  845: 'hee',
#  846: 'savamob',
#  847: 'download',
#  848: 'mu',
#  849: 'gal',
#  850: 'fone',
#  851: 'rental',
#  852: '12',
#  853: 'txts',
#  854: 'wine',
#  855: 'hg',
#  856: 'w1j6hl',
#  857: 'dogging',
#  858: 'area',
#  859: '2003',
#  860: '800',
#  861: 'un',
#  862: 'gas',
#  863: 'log',
#  864: 'christmas',
#  865: 'usf',
#  866: 'invited',
#  867: 'decided',
#  868: 'mom',
#  869: 'correct',
#  870: 'offers',
#  871: 'read',
#  872: 'eg',
#  873: 'used',
#  874: 'balance',
#  875: 'confirm',
#  876: 'father',
#  877: 'ten',
#  878: 'takes',
#  879: 'hungry',
#  880: "'",
#  881: 'fancy',
#  882: 'blue',
#  883: 'exam',
#  884: 'services',
#  885: 'direct',
#  886: 'wrong',
#  887: 'mah',
#  888: 'yr',
#  889: 'surprise',
#  890: 'computer',
#  891: 'laptop',
#  892: '87066',
#  893: 'happiness',
#  894: 'red',
#  895: 'police',
#  896: 'valued',
#  897: 'sex',
#  898: 'wonder',
#  899: '\x89û',
#  900: '08000839402',
#  901: 'prob',
#  902: 'wow',
#  903: 'tel',
#  904: 'heard',
#  905: 'tired',
#  906: 'fr',
#  907: 'bank',
#  908: 'park',
#  909: 'ldn',
#  910: 'picking',
#  911: 'match',
#  912: 'redeemed',
#  913: 'merry',
#  914: "wasn't",
#  915: 'del',
#  916: 'small',
#  917: 'std',
#  918: 'mr',
#  919: 'grins',
#  920: 'john',
#  921: 'own',
#  922: 'knew',
#  923: 'drugs',
#  924: 'save',
#  925: 'reveal',
#  926: 'thinks',
#  927: 'meant',
#  928: 'jay',
#  929: 'across',
#  930: 'bslvyl',
#  931: 'voice',
#  932: 'crave',
#  933: 'asap',
#  934: 'march',
#  935: 'gotta',
#  936: 'st',
#  937: 'gym',
#  938: 'o',
#  939: 'rock',
#  940: 'paper',
#  941: 'swing',
#  942: 'whenever',
#  943: 'extra',
#  944: 'information',
#  945: '2nite',
#  946: 'p',
#  947: 'seen',
#  948: 'energy',
#  949: 'ans',
#  950: 'yar',
#  951: 'nyt',
#  952: 'reward',
#  953: 'within',
#  954: 'th',
#  955: 'store',
#  956: 'kate',
#  957: 'darren',
#  958: 'tickets',
#  959: 'via',
#  960: 'mate',
#  961: 'laugh',
#  962: 'tonite',
#  963: 'sound',
#  964: 'comin',
#  965: 'currently',
#  966: 'clean',
#  967: 'blood',
#  968: 'figure',
#  969: 'poor',
#  970: 'through',
#  971: 'rest',
#  972: 'convey',
#  973: 'em',
#  974: 'moment',
#  975: 'felt',
#  976: 'gn',
#  977: 'deep',
#  978: 'ringtones',
#  979: "i'd",
#  980: 'call2optout',
#  981: 'ending',
#  982: 'rates',
#  983: 'otherwise',
#  984: 'noon',
#  985: '04',
#  986: 'ex',
#  987: 'muz',
#  988: 'yep',
#  989: '150',
#  990: 'sony',
#  991: 'press',
#  992: 'wap',
#  993: 'bill',
#  994: 'dream',
#  995: 'warm',
#  996: 'reached',
#  997: 'hospital',
#  998: 'gets',
#  999: 'xy',
#  1000: 'side',
#  ...}

# %%
TOT_SIZE = len(tok.word_index)+1
lstm_model = Sequential()
lstm_model.add(Embedding(TOT_SIZE, 32, input_length=max_len))
lstm_model.add(LSTM(100))
lstm_model.add(Dropout(0.4))
lstm_model.add(Dense(20, activation="relu"))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(1, activation = "sigmoid"))

# %%
lstm_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 32)           262304
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 317,545
# Trainable params: 317,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(sequences_matrix,Y_train,batch_size=128,epochs=10,
          validation_split=0.2,
          workers=10,
           callbacks=[EarlyStopping(monitor='val_loss',min_delta=0.0001)])
# Out:
# Epoch 1/10
# 30/30 [==============================] - 9s 225ms/step - loss: 0.5008 - accuracy: 0.8329 - val_loss: 0.3201 - val_accuracy: 0.8734
# Epoch 2/10
# 30/30 [==============================] - 6s 211ms/step - loss: 0.2156 - accuracy: 0.9295 - val_loss: 0.1044 - val_accuracy: 0.9715

# %%
lstm_model.save('sms.h5')

# %%
test_sequences = tok.texts_to_sequences(X_test)
test_sequences_matrix = pad_sequences(test_sequences,maxlen=max_len)

# %%
acc = lstm_model.evaluate(test_sequences_matrix,Y_test)
# Out:
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0846 - accuracy: 0.9737

# %%
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(acc[0],acc[1]))
# Out:
# Test set
#   Loss: 0.085
#   Accuracy: 0.974
